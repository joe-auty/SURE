# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
print(pd.__version__)
data1=pd.read_csv(r"C:\Users\Joe Auty\Documents\SURE\data\resureintro\data1.csv")
data2=pd.read_csv(r"C:\Users\Joe Auty\Documents\SURE\data\resureintro\data2.csv")
data3=pd.read_csv(r"C:\Users\Joe Auty\Documents\SURE\data\resureintro\data3.csv")
# Out:
# 0.24.2

# %%
a=np.size(data1.power_avg)
y1=data1['power_avg'];
x1=data1['windspeed_avg']
z1=data1['turbine_state']
colors=np.zeros(a)
y2=data2['power_avg'];
x2=data2['windspeed_avg']
y3=data3['power_avg'];
x3=data3['windspeed_avg']
plt.figure()
f = plt.figure(figsize=(30,40))
plt.subplot(311)
plt.scatter(x1,y1)
plt.xlabel('average wind speed',fontsize=40)
plt.ylabel('average power',fontsize=40)
plt.title('data1-manor farm',fontsize=40)

plt.subplot(312)
plt.scatter(x2,y2)
plt.xlabel('average wind speed',fontsize=40)
plt.ylabel('average power',fontsize=40)
plt.title('data2 hobson',fontsize=40)

plt.subplot(313)
plt.scatter(x3,y3)
plt.xlabel('average wind speed',fontsize=40)
plt.ylabel('average power',fontsize=40)
plt.title('data3 - stephenson',fontsize=40)
# Out:
# Text(0.5, 1.0, 'data3 - stephenson')

# %%
a=np.asarray(np.where(states==0))
b=np.asarray(np.where(states==1))
c=np.asarray(np.where(states==2)) 
d=np.asarray(np.where(states==3)) 
e=np.asarray(np.where(states==4)) 
f=np.asarray(np.where(states==5))
g=np.asarray(np.where(states==6)) 
h=np.asarray(np.where(states==7)) 

y3_0=[y3[i] for i in a]
x3_0=[x3[i] for i in a]
y3_1=[y3[i] for i in b]
x3_1=[x3[i] for i in b]
y3_2=[y3[i] for i in c]
x3_2=[x3[i] for i in c]
y3_3=[y3[i] for i in d]
x3_3=[x3[i] for i in d]
y3_4=[y3[i] for i in e]
x3_4=[x3[i] for i in e]
y3_5=[y3[i] for i in f]
x3_5=[x3[i] for i in f]
y3_6=[y3[i] for i in g]
x3_6=[x3[i] for i in g]
y3_7=[y3[i] for i in h]
x3_7=[x3[i] for i in h]

# %%
states=data3['turbine_state']
k=len(states)




fig=plt.figure(1)
ax=fig.add_subplot(111)
ax.plot(x3_0,y3_0,'ro',label='class 0')
ax.plot(x3_1,y3_1,'bo',label='class 1')
# for some reason python doesn't seem to like it when i try to plot state 2 data 
ax.plot(x3_3,y3_3,'mo',label='class 3')
ax.plot(x3_4,y3_4,'yo',label='class 4')
ax.plot(x3_5,y3_5,'wo',label='class 5')
ax.plot(x3_6,y3_6,'co',label='class 6')
ax.plot(x3_7,y3_7,'ko',label='class 7')
#ax.legend(loc='upper left')
#adding seems legend makes figure 'too large' 
#error message "Image size of 372x254875 pixels is too large. It must be less than 2^16 in each direction.

plt.show()

# %%
type(x3_0)

# %%
type(x3)
